# %% [markdown]
# <a href="https://colab.research.google.com/github/shravani87-p/Cancer-Prediction/blob/main/ShravaniPotdukhe_CancerPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Title of Project
# Cancer Prediction Using Logistic Regression
#
# ### Objective
# To predict whether a given tumor is benign (B) or malignant (M) based on various features of cell nuclei present in the dataset.
#
# ### Data Source
# https://github.com/YBIFoundation/Dataset/raw/main/Cancer.csv
#
# ### Import Library
# ```python
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# ```
#
# ### Import Data
# ```python
# cancer = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Cancer.csv')
# ```
#
# ### Describe Data
# ```python
# print(cancer.head())
# print(cancer.info())
# print(cancer.describe())
# ```
#
# ### Data Visualization
# For this example, no specific data visualization steps are included. However, visualizing the data can provide insights into feature distributions and relationships.
#
# ### Data Preprocessing
# ```python
# # Drop unnecessary columns
# cancer = cancer.drop(['id', 'Unnamed: 32'], axis=1)
#
# # Encode the target variable
# cancer['diagnosis'] = cancer['diagnosis'].map({'M': 1, 'B': 0})
# ```
#
# ### Define Target Variable (y) and Feature Variables (X)
# ```python
# y = cancer['diagnosis']
# X = cancer.drop(['diagnosis'], axis=1)
# ```
#
# ### Train Test Split
# ```python
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2529)
#
# # Check shape of train and test samples
# print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# ```
#
# ### Modeling
# ```python
# model = LogisticRegression(max_iter=5000)
#
# # Train or fit model
# model.fit(X_train, y_train)
# ```
#
# ### Model Evaluation
# ```python
# # Predict the test set results
# y_pred = model.predict(X_test)
#
# # Confusion Matrix
# print(confusion_matrix(y_test, y_pred))
#
# # Accuracy Score
# print(accuracy_score(y_test, y_pred))
#
# # Classification Report
# print(classification_report(y_test, y_pred))
# ```
#
# ### Prediction
# ```python
# # Example of predicting with the model
# y_pred = model.predict(X_test)
# print(y_pred)
# ```
#
# ### Explanation
# - **Title of Project:** Cancer Prediction Using Logistic Regression
# - **Objective:** Predict whether a tumor is benign or malignant.
# - **Data Source:** The dataset is sourced from a CSV file available at the provided URL.
# - **Import Library:** Required libraries are imported for data manipulation, model building, and evaluation.
# - **Import Data:** The dataset is loaded using `pandas.read_csv`.
# - **Describe Data:** Initial data inspection is performed using `head`, `info`, and `describe` methods to understand the structure and summary statistics.
# - **Data Visualization:** While not included in this example, data visualization can be performed to explore feature distributions and relationships.
# - **Data Preprocessing:** Unnecessary columns are dropped, and the target variable is encoded.
# - **Define Target Variable (y) and Feature Variables (X):** The target and features are defined for model training.
# - **Train Test Split:** The dataset is split into training and testing sets.
# - **Modeling:** A logistic regression model is selected and trained on the training data.
# - **Model Evaluation:** The model is evaluated using confusion matrix, accuracy score, and classification report to determine its performance.
# - **Prediction:** The model is used to make predictions on the test data.

# %% [markdown]
# Results :

# %%
# Import Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Import Data
cancer = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Cancer.csv')

# Describe Data
print(cancer.head())
print(cancer.info())
print(cancer.describe())

# Data Preprocessing
# Drop unnecessary columns
cancer = cancer.drop(['id', 'Unnamed: 32'], axis=1)

# Encode the target variable
cancer['diagnosis'] = cancer['diagnosis'].map({'M': 1, 'B': 0})

# Define Target Variable (y) and Feature Variables (X)
y = cancer['diagnosis']
X = cancer.drop(['diagnosis'], axis=1)

# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2529)

# Check shape of train and test samples
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# Modeling
model = LogisticRegression(max_iter=5000)

# Train or fit model
model.fit(X_train, y_train)

# Model Evaluation
# Predict the test set results
y_pred = model.predict(X_test)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

# Accuracy Score
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Classification Report
report = classification_report(y_test, y_pred)
print(report)

# Visualization of Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant'], yticklabels=['Benign', 'Malignant'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Visualization of Accuracy Score
plt.figure(figsize=(6, 4))
plt.bar(['Accuracy'], [accuracy], color='skyblue')
plt.ylim(0, 1)
plt.title('Model Accuracy')
plt.show()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...
